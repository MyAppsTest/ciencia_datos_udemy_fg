# %% [markdown]
# <a href="https://colab.research.google.com/github/MyAppsTest/ciencia_datos_udemy_fg/blob/main/CienciaDeDatos_con_Federico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Curso de ciencia de datos con Federico Garay

# %% [markdown]
# ##Operaciones

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
link = "/content/drive/MyDrive/cd_udemy_fg/Precipitaciones.csv"

# %%
import pandas as pd

# %%
df = pd.read_csv(link)

# %%
df
# Out:
#                     region  enero  febrero  marzo  abril   mayo  junio  julio  \
# 0                 A CORUNA  240.5    293.4   31.0   80.6  149.5  108.9   44.6
# 1                 ALBACETE   68.1     28.0   26.2   65.3   25.4   50.0    2.0
# 2                 ALICANTE   49.2      3.7   63.2   85.8   57.2   20.0    9.2
# 3                  ALMERIA   56.3      5.2   35.8   43.1   38.8   16.9   10.2
# 4                    ARABA   96.8     79.9   38.0   52.0   37.7  107.8    8.5
# 5                 ASTURIAS  196.9    138.4   34.4   73.1   67.4  131.2   22.5
# 6                    AVILA   67.6    104.5    5.6   83.4   25.7   44.4    5.5
# 7                  BADAJOZ   62.2     78.5    7.7   61.3   13.0   29.6    0.0
# 8            ILLES BALEARS   81.2      5.3   53.9   22.0   54.4   28.5    8.8
# 9                BARCELONA   26.8     28.4   16.4   72.2   26.0   42.3   18.7
# 10                 BIZKAIA  175.7    111.5   52.3   57.5   49.1  124.8   37.9
# ...

# %%
df.head(3)
# Out:
#      region  enero  febrero  marzo  abril   mayo  junio  julio  agosto  \
# 0  A CORUNA  240.5    293.4   31.0   80.6  149.5  108.9   44.6    21.8
# 1  ALBACETE   68.1     28.0   26.2   65.3   25.4   50.0    2.0    34.5
# 2  ALICANTE   49.2      3.7   63.2   85.8   57.2   20.0    9.2     5.0
#
#    septiembre  octubre  noviembre  diciembre   anual
# 0        96.5    154.5      100.8      214.8  1536.9
# 1        48.0     44.8       33.1       14.1   439.5
# 2        44.0     41.1       47.4        1.8   427.6

# %%
df.tail()
# Out:
#         region  enero  febrero  marzo  abril  mayo  junio  julio  agosto  \
# 47      TOLEDO   83.0     51.1    7.5   62.5  15.0   27.1    3.3    18.6
# 48    VALENCIA   61.9     16.8   49.3   86.4  33.8   34.2   17.1    30.9
# 49  VALLADOLID   29.2     69.1    4.1   65.1  24.3   58.3    1.9     3.8
# 50      ZAMORA   53.0    112.0    6.8   63.7  19.8   54.2    3.1     9.6
# 51    ZARAGOZA   52.0     30.0    3.6   52.7  38.3   57.5   13.5    13.2
#
#     septiembre  octubre  noviembre  diciembre  anual
# 47        70.5     94.7       16.4       29.9  479.6
# 48        99.3     46.1       46.6        5.5  527.9
# 49        54.1     40.2       41.7       35.9  427.7
# 50        78.5     55.3       29.0       50.3  535.3
# 51        61.5     27.4       76.6       23.4  449.7

# %%
df.shape
# Out:
# (52, 14)

# %%
df.columns
# Out:
# Index(['region', 'enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio',
#        'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre',
#        'anual'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      52 non-null     object
#  1   enero       52 non-null     float64
#  2   febrero     52 non-null     float64
#  3   marzo       52 non-null     float64
#  4   abril       52 non-null     float64
#  5   mayo        52 non-null     float64
#  6   junio       52 non-null     float64
#  7   julio       52 non-null     float64
#  8   agosto      52 non-null     float64
#  9   septiembre  52 non-null     float64
#  10  octubre     52 non-null     float64
#  11  noviembre   52 non-null     float64
#  12  diciembre   52 non-null     float64
#  13  anual       52 non-null     float64
# dtypes: float64(13), object(1)
# memory usage: 5.8+ KB

# %%
df.describe()
# Out:
#             enero     febrero       marzo       abril        mayo       junio  \
# count   52.000000   52.000000   52.000000   52.000000   52.000000   52.000000
# mean    92.996154   78.632692   26.684615   64.500000   38.305769   54.182692
# std     57.127171   67.454280   31.473913   21.421942   29.079576   36.821635
# min     26.800000    2.300000    3.300000    3.500000    0.700000    1.100000
# 25%     53.825000   32.825000    9.125000   53.950000   18.875000   26.325000
# 50%     73.950000   62.600000   17.200000   62.700000   35.650000   50.400000
# 75%     97.300000  102.550000   35.425000   77.625000   48.750000   78.025000
# max    261.900000  335.700000  209.800000  128.400000  149.500000  145.000000
#
#            julio     agosto  septiembre     octubre   noviembre   diciembre  \
# count  52.000000  52.000000   52.000000   52.000000   52.000000   52.000000
# mean   11.840385  17.178846   62.246154   54.373077   82.494231   76.192308
# ...

# %%
serie = df["region"]

# %%
serie
# Out:
# 0                   A CORUNA
# 1                   ALBACETE
# 2                   ALICANTE
# 3                    ALMERIA
# 4                      ARABA
# 5                   ASTURIAS
# 6                      AVILA
# 7                    BADAJOZ
# 8              ILLES BALEARS
# 9                  BARCELONA
# 10                   BIZKAIA
# 11                    BURGOS
# 12                   CACERES
# 13                     CADIZ
# 14                 CANTABRIA
# 15                 CASTELLON
# 16                     CEUTA
# 17               CIUDAD REAL
# 18                   CORDOBA
# 19                    CUENCA
# 20                  GIPUZKOA
# 21                    GIRONA
# 22                   GRANADA
# 23               GUADALAJARA
# 24                    HUELVA
# 25                    HUESCA
# 26                      JAEN
# 27                  LA RIOJA
# 28                LAS PALMAS
# 29                      LEON
# 30                    LLEIDA
# 31                      LUGO
# ...

# %%
#Creando una seria (columna)
datos = [10,20,30,40,50]

# %%
serie2 = pd.Series(datos)

# %%
serie2
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#creando indices
indices=["a", "b", "c", "d", "e"]

# %%
serie2= pd.Series(datos,indices)

# %%
serie2
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
#creando una serie con un diccionario
capitales = {"España": "Madrid", "Perú": "Lima", "Argentina":"Buenos Aires"}

# %%
serie3 = pd.Series(capitales)

# %%
serie3
# Out:
# España             Madrid
# Perú                 Lima
# Argentina    Buenos Aires
# dtype: object

# %%
serie3["Perú"]
# Out:
# 'Lima'

# %%
serie = pd.Series([10,20,30,40,50])

# %%
#suma 10 al valor del indice 0.
serie[0] = serie[0] + 10

# %%
serie
# Out:
# 0    20
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#suma 10 a todos los valores de la serie
serie = serie +10

# %%
serie
# Out:
# 0    30
# 1    30
# 2    40
# 3    50
# 4    60
# dtype: int64

# %%
#multiplica por 2 los valores de la serie
serie = serie * 2

# %%
serie
# Out:
# 0     60
# 1     60
# 2     80
# 3    100
# 4    120
# dtype: int64

# %% [markdown]
# ##Limpieza de datos

# %%
import pandas as pd

# %%
data = {"Id_producto": [1001,1002,1003,1003],
        "Cantidad_vendida": [30, None, 25,25],
        "Precio": [20.5,15.0,None,22.5]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Id_producto  Cantidad_vendida  Precio
# 0         1001              30.0    20.5
# 1         1002               NaN    15.0
# 2         1003              25.0     NaN
# 3         1003              25.0    22.5

# %%
df.isnull()
# Out:
#    Id_producto  Cantidad_vendida  Precio
# 0        False             False   False
# 1        False              True   False
# 2        False             False    True
# 3        False             False   False

# %%
df.isnull().sum()
# Out:
# Id_producto         0
# Cantidad_vendida    1
# Precio              1
# dtype: int64

# %%
#eliminando vacios
df_eliminados = df.dropna()

# %%
df_eliminados
# Out:
#    Id_producto  Cantidad_vendida  Precio
# 0         1001              30.0    20.5
# 3         1003              25.0    22.5

# %%
#cambiar valores nulos por otro valor
valores_nulos = {"Cantidad_vendida":0, "Precio": df["Precio"].mean()}

# %%
df_rellenados = df.fillna(valores_nulos)

# %%
df_rellenados
# Out:
#    Id_producto  Cantidad_vendida     Precio
# 0         1001              30.0  20.500000
# 1         1002               0.0  15.000000
# 2         1003              25.0  19.333333
# 3         1003              25.0  22.500000

# %%
df_rellenados["Total"] = df_rellenados["Cantidad_vendida"] * df_rellenados["Precio"]

# %%
df_rellenados
# Out:
#    Id_producto  Cantidad_vendida     Precio       Total
# 0         1001              30.0  20.500000  615.000000
# 1         1002               0.0  15.000000    0.000000
# 2         1003              25.0  19.333333  483.333333
# 3         1003              25.0  22.500000  562.500000

# %%
df_rellenados["Cantidad_vendida"] = df_rellenados["Cantidad_vendida"].astype(int)

# %%
df_rellenados
# Out:
#    Id_producto  Cantidad_vendida     Precio       Total
# 0         1001                30  20.500000  615.000000
# 1         1002                 0  15.000000    0.000000
# 2         1003                25  19.333333  483.333333
# 3         1003                25  22.500000  562.500000

# %%
df_unicos = df_rellenados.drop_duplicates(subset="Id_producto")

# %%
df_unicos
# Out:
#    Id_producto  Cantidad_vendida     Precio       Total
# 0         1001                30  20.500000  615.000000
# 1         1002                 0  15.000000    0.000000
# 2         1003                25  19.333333  483.333333

# %%
df_unicos[df_unicos["Precio"]>15]
# Out:
#    Id_producto  Cantidad_vendida     Precio       Total
# 0         1001                30  20.500000  615.000000
# 2         1003                25  19.333333  483.333333

# %% [markdown]
# ##Filtro de series en Pandas

# %%
import pandas as pd

# %% [markdown]
# ###filtro numericos

# %%
serie = pd.Series([5,10,15,20,25])

# %%
serie
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
#crea una variable con los criterios del filtro
filtro = serie > 15

# %%
serie_filtrada = serie[filtro]

# %%
serie_filtrada
# Out:
# 3    20
# 4    25
# dtype: int64

# %% [markdown]
# ###Filtros string

# %%
serie2 = pd.Series(["banana", "pera", "melon", "manzana"])

# %%
serie2
# Out:
# 0     banana
# 1       pera
# 2      melon
# 3    manzana
# dtype: object

# %%
#dir(serie2)

# %%
#help(serie2.str)

# %%
filtro2 = serie2.str.contains("m" )

# %%
serie2[filtro2]
# Out:
# 2      melon
# 3    manzana
# dtype: object

# %% [markdown]
# ##Agregando (calculos) series en Pandas

# %%
import pandas as pd

# %%
numeros = pd.Series([10,20,30,40,50])

# %%
numeros
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#promedio
promedio = numeros.mean()
print(f"El promedio es: {promedio}")
# Out:
# El promedio es: 30.0

# %%
#suma
total = numeros.sum()
print(f"El total es: {total}")
# Out:
# El total es: 150

# %%
#maximo
maximo = numeros.max()
print(f"El total es: {maximo}")
# Out:
# El total es: 50

# %%
#minimo
minimo = numeros.min()
print(f"El total es: {minimo}")
# Out:
# El total es: 10

# %% [markdown]
# ##Dataframes con Pandas

# %%
import pandas as pd

# %%
data = { "nombre":["Ana", "Luis", "Carlos", "Sara"],
        "edad" : [25,30,22,27],
         "ciudad": ["Madrid", "Barcelona", "Valencia", "Bilbao"]
    }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    nombre  edad     ciudad
# 0     Ana    25     Madrid
# 1    Luis    30  Barcelona
# 2  Carlos    22   Valencia
# 3    Sara    27     Bilbao

# %%
#agregando columnas
df["salario"] = [30000,45000,38000,32000]

# %%
df
# Out:
#    nombre  edad     ciudad  salario
# 0     Ana    25     Madrid    30000
# 1    Luis    30  Barcelona    45000
# 2  Carlos    22   Valencia    38000
# 3    Sara    27     Bilbao    32000

# %%
df['salario'] = df['salario'] + 2000

# %%
df
# Out:
#    nombre  edad     ciudad  salario
# 0     Ana    25     Madrid    32000
# 1    Luis    30  Barcelona    47000
# 2  Carlos    22   Valencia    40000
# 3    Sara    27     Bilbao    34000

# %%
nombres = df['nombre']

# %%
nombres
# Out:
# 0       Ana
# 1      Luis
# 2    Carlos
# 3      Sara
# Name: nombre, dtype: object

# %%
mayores_25 = df[df['edad']>25]

# %%
mayores_25
# Out:
#   nombre  edad     ciudad  salario
# 1   Luis    30  Barcelona    47000
# 3   Sara    27     Bilbao    34000

# %% [markdown]
# ##Ordenar y agrupar dataframes

# %%
import pandas as pd

# %%
link = "/content/drive/MyDrive/cd_udemy_fg/Top-Películas.csv"

# %%
df = pd.read_csv(link)

# %%
df
# Out:
#      indice_global  indice_estricto                    título  \
# 0                0              0.0  The Shawshank Redemption
# 1                1              1.0             The Godfather
# 2                2              1.0             The Godfather
# 3                3              2.0           The Dark Knight
# 4                4              2.0           The Dark Knight
# ...            ...              ...                       ...
# 2527          2527            998.0         The Invisible Man
# 2528          2528            998.0         The Invisible Man
# 2529          2529            999.0                  Cell 211
# 2530          2530            999.0                  Cell 211
# 2531          2531            999.0                  Cell 211
#
#                   director     año  duración           género  rating  \
# 0           Frank Darabont  1994.0     142.0            Drama     9.3
# 1     Francis Ford Coppola  1972.0     175.0           Crimen     9.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2532 entries, 0 to 2531
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   indice_global    2532 non-null   object
#  1   indice_estricto  2489 non-null   float64
#  2   título           2489 non-null   object
#  3   director         2489 non-null   object
#  4   año              2489 non-null   float64
#  5   duración         2489 non-null   float64
#  6   género           2489 non-null   object
#  7   rating           2489 non-null   float64
#  8   metascore        2489 non-null   float64
#  9   recaudación(M)   2489 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 197.9+ KB

# %%
df.isnull().sum()
# Out:
# indice_global       0
# indice_estricto    43
# título             43
# director           43
# año                43
# duración           43
# género             43
# rating             43
# metascore          43
# recaudación(M)     43
# dtype: int64

# %%
df.isnull()
# Out:
#       indice_global  indice_estricto  título  director    año  duración  \
# 0             False            False   False     False  False     False
# 1             False            False   False     False  False     False
# 2             False            False   False     False  False     False
# 3             False            False   False     False  False     False
# 4             False            False   False     False  False     False
# ...             ...              ...     ...       ...    ...       ...
# 2527          False            False   False     False  False     False
# 2528          False            False   False     False  False     False
# 2529          False            False   False     False  False     False
# 2530          False            False   False     False  False     False
# 2531          False            False   False     False  False     False
#
#       género  rating  metascore  recaudación(M)
# 0      False   False      False           False
# ...

# %%
#ordenar por 1 columna
df_ordenado = df.sort_values(by="rating", ascending=False)

# %%
df_ordenado.head(10)
# Out:
#    indice_global  indice_estricto  \
# 0              0              0.0
# 1              1              1.0
# 2              2              1.0
# 5              5              2.0
# 12            12              5.0
# 14            14              6.0
# 10            10              4.0
# 6              6              3.0
# 15            15              6.0
# 9              9              4.0
#
#                                            título              director  \
# 0                        The Shawshank Redemption        Frank Darabont
# 1                                   The Godfather  Francis Ford Coppola
# 2                                   The Godfather  Francis Ford Coppola
# 5                                 The Dark Knight     Christopher Nolan
# 12  The Lord of the Rings: The Return of the King         Peter Jackson
# 14                          The Godfather Part II  Francis Ford Coppola
# 10                                   12 Angry Men          Sidney Lumet
# ...

# %%
#ordenar por 2 columnas
df_ordenado = df.sort_values(by=["rating", "recaudación(M)"], ascending=False)

# %%
df_ordenado.head(10)
# Out:
#    indice_global  indice_estricto  \
# 0              0              0.0
# 1              1              1.0
# 2              2              1.0
# 3              3              2.0
# 4              4              2.0
# 5              5              2.0
# 11            11              5.0
# 12            12              5.0
# 13            13              5.0
# 6              6              3.0
#
#                                            título              director  \
# 0                        The Shawshank Redemption        Frank Darabont
# 1                                   The Godfather  Francis Ford Coppola
# 2                                   The Godfather  Francis Ford Coppola
# 3                                 The Dark Knight     Christopher Nolan
# 4                                 The Dark Knight     Christopher Nolan
# 5                                 The Dark Knight     Christopher Nolan
# 11  The Lord of the Rings: The Return of the King         Peter Jackson
# ...

# %%
df_agrupado = df.groupby("género")["rating"].mean()

# %%
df_agrupado
# Out:
# género
# Acción             7.987255
# Animación          7.943902
# Aventura           7.980435
# Biografía          7.971698
# Ciencia Ficción    7.986567
# Comedia            7.909910
# Crimen             7.993500
# Deportes           7.980000
# Drama              7.980444
# Familiar           7.932692
# Fantasía           7.929508
# Film-Noir          7.977273
# Guerra             8.053191
# Historia           7.931818
# Misterio           7.991262
# Musica             7.909677
# Musical            7.943750
# Romance            7.937398
# Terror             7.875758
# Thriller           7.929286
# Western            8.006250
# Name: rating, dtype: float64

# %%
df.agrupado = df.groupby('año')['recaudación(M)'].sum()
# Out:
# <ipython-input-94-bd8aac70a9a7>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.agrupado = df.groupby('año')['recaudación(M)'].sum()

# %%
df.agrupado.sort_values(ascending=False).head(10)
# Out:
# año
# 2014.0    8015.90
# 2019.0    7092.95
# 2010.0    6899.96
# 2016.0    6860.23
# 2015.0    6817.12
# 2012.0    6487.22
# 2009.0    6486.34
# 2018.0    5992.02
# 2008.0    5603.30
# 2017.0    5381.90
# Name: recaudación(M), dtype: float64

# %% [markdown]
# ##Fusionar DataFrames

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({ 'id' : [1,2,3], 'nombre': ['Ana', 'Luis','Carlos']})
df2 = pd.DataFrame({ 'id': [1,2,4], 'edad': [25,30,22]})

# %%
df1
# Out:
#    id  nombre
# 0   1     Ana
# 1   2    Luis
# 2   3  Carlos

# %%
df2
# Out:
#    id  edad
# 0   1    25
# 1   2    30
# 2   4    22

# %%
#combinar dataframes con coincidencias
df_combinado = pd.merge(df1,df2, on='id', how='inner')

# %%
df_combinado
# Out:
#    id nombre  edad
# 0   1    Ana    25
# 1   2   Luis    30

# %%
#combinar dataframes con todos los valores de ambos
df_combinado = pd.merge(df1,df2, on='id', how='outer')

# %%
df_combinado
# Out:
#    id  nombre  edad
# 0   1     Ana  25.0
# 1   2    Luis  30.0
# 2   3  Carlos   NaN
# 3   4     NaN  22.0

# %%
#combinar dataframes, completa los valores en la df1 (izquierda) con las coincidencias de la df2 (derecha)
df_combinado = pd.merge(df1,df2, on='id', how='left')

# %%
df_combinado
# Out:
#    id  nombre  edad
# 0   1     Ana  25.0
# 1   2    Luis  30.0
# 2   3  Carlos   NaN

# %%
#combinar dataframes, completa los valores en la df2 (derecha) con las coincidencias de la df1 (izquierda)
df_combinado = pd.merge(df1,df2, on='id', how='right')

# %%
df_combinado
# Out:
#    id nombre  edad
# 0   1    Ana    25
# 1   2   Luis    30
# 2   4    NaN    22

# %%
#agregando los indices de cada lado
df_indexado = pd.merge(df1, df2, left_index=True, right_index=True)

# %%
df_indexado
# Out:
#    id_x  nombre  id_y  edad
# 0     1     Ana     1    25
# 1     2    Luis     2    30
# 2     3  Carlos     4    22

# %% [markdown]
# ##Combinar DataFrames en pandas con join()

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'salario': [30000,45000,30000],
                    'antiguedad': [9,13,12]},
                    index=[1,2,3])

# %%
df2 = pd.DataFrame({'ciudad':['madrid', 'barcelona', 'valencia'],
        'jerarquia':['baja', 'alta', 'media']},index=[1,2,4])

# %%
df1
# Out:
#    salario  antiguedad
# 1    30000           9
# 2    45000          13
# 3    30000          12

# %%
df2
# Out:
#       ciudad jerarquia
# 1     madrid      baja
# 2  barcelona      alta
# 4   valencia     media

# %%
df_unido = df1.join(df2)

# %%
df_unido
# Out:
#    salario  antiguedad     ciudad jerarquia
# 1    30000           9     madrid      baja
# 2    45000          13  barcelona      alta
# 3    30000          12        NaN       NaN

# %%
df_unido = df1.join(df2, how='inner')
df_unido
# Out:
#    salario  antiguedad     ciudad jerarquia
# 1    30000           9     madrid      baja
# 2    45000          13  barcelona      alta

# %%
df_unido = df1.join(df2, how='outer')
df_unido
# Out:
#    salario  antiguedad     ciudad jerarquia
# 1  30000.0         9.0     madrid      baja
# 2  45000.0        13.0  barcelona      alta
# 3  30000.0        12.0        NaN       NaN
# 4      NaN         NaN   valencia     media

# %% [markdown]
# ##Concatenar dataframes

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'nombre': ['juan', 'gabriela', 'elena'], 'edad': [23,31,21]})
df1
# Out:
#      nombre  edad
# 0      juan    23
# 1  gabriela    31
# 2     elena    21

# %%
df2 = pd.DataFrame({'nombre': ['carmela', 'max','laura'], 'edad':[34,25,29]})
df2
# Out:
#     nombre  edad
# 0  carmela    34
# 1      max    25
# 2    laura    29

# %%
df_concatenado = pd.concat([df1,df2])

# %%
df_concatenado
# Out:
#      nombre  edad
# 0      juan    23
# 1  gabriela    31
# 2     elena    21
# 0   carmela    34
# 1       max    25
# 2     laura    29

# %%
df_concatenado2 = pd.concat([df1,df2], axis=1)

# %%
df_concatenado2
# Out:
#      nombre  edad   nombre  edad
# 0      juan    23  carmela    34
# 1  gabriela    31      max    25
# 2     elena    21    laura    29

# %%
df_concatenado = pd.concat([df1,df2], ignore_index=True)

# %%
df_concatenado
# Out:
#      nombre  edad
# 0      juan    23
# 1  gabriela    31
# 2     elena    21
# 3   carmela    34
# 4       max    25
# 5     laura    29

# %%
df_concatenado = pd.concat([df1,df2], keys=['df1','df2'])

# %%
df_concatenado
# Out:
#          nombre  edad
# df1 0      juan    23
#     1  gabriela    31
#     2     elena    21
# df2 0   carmela    34
#     1       max    25
#     2     laura    29

# %% [markdown]
# ##Datos relacionado con el tiempo

# %%
import pandas as pd

# %%
link = "/content/drive/MyDrive/cd_udemy_fg/Mercado+de+Valores+España.csv"

# %%
df = pd.read_csv(link)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8575 entries, 0 to 8574
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ticker      8575 non-null   object
#  1   Fecha       8575 non-null   object
#  2   Cierre      8575 non-null   float64
#  3   Referencia  8575 non-null   float64
#  4   Volumen     8575 non-null   int64
#  5   Rotacion    8575 non-null   float64
#  6   Ultimo      8575 non-null   float64
#  7   Alto        8575 non-null   float64
#  8   Bajo        8575 non-null   float64
#  9   Promedio    8575 non-null   float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 670.1+ KB

# %%
df.head(5)
# Out:
#   Ticker       Fecha  Cierre  Referencia  Volumen     Rotacion  Ultimo   Alto  \
# 0    ANA  02/01/2019   74.80       73.90   156300  11621188.98   74.80  75.16
# 1    ANA  03/01/2019   76.34       74.80   140331  10632703.64   76.34  76.60
# 2    ANA  04/01/2019   76.62       76.34   130309  10010838.76   76.62  77.40
# 3    ANA  07/01/2019   77.14       76.62    63349   4855724.92   77.14  77.30
# 4    ANA  08/01/2019   78.24       77.14    99300   7749464.70   78.24  78.46
#
#     Bajo  Promedio
# 0  72.38   74.3518
# 1  74.54   75.7687
# 2  76.40   76.8162
# 3  75.62   76.6504
# 4  77.00   78.0409

# %%
fechas = pd.Series(pd.date_range('20240101', periods=6))

# %%
fechas
# Out:
# 0   2024-01-01
# 1   2024-01-02
# 2   2024-01-03
# 3   2024-01-04
# 4   2024-01-05
# 5   2024-01-06
# dtype: datetime64[ns]

# %%
# con una frecuencia (freq) mensual.
fechas = pd.Series(pd.date_range('20240101', periods=6, freq='ME'))
fechas
# Out:
# 0   2024-01-31
# 1   2024-02-29
# 2   2024-03-31
# 3   2024-04-30
# 4   2024-05-31
# 5   2024-06-30
# dtype: datetime64[ns]

# %%
#con una frecuencia (freq) de cada 5 dias.
fechas = pd.Series(pd.date_range('20240101', periods=6, freq='5D'))
fechas
# Out:
# 0   2024-01-01
# 1   2024-01-06
# 2   2024-01-11
# 3   2024-01-16
# 4   2024-01-21
# 5   2024-01-26
# dtype: datetime64[ns]

# %%
#convertir str a fecha
df['Fecha'] = pd.to_datetime(df['Fecha'], format='%d/%m/%Y')

# %%
df
# Out:
#      Ticker      Fecha  Cierre  Referencia  Volumen     Rotacion  Ultimo  \
# 0       ANA 2019-01-02   74.80       73.90   156300  11621188.98   74.80
# 1       ANA 2019-01-03   76.34       74.80   140331  10632703.64   76.34
# 2       ANA 2019-01-04   76.62       76.34   130309  10010838.76   76.62
# 3       ANA 2019-01-07   77.14       76.62    63349   4855724.92   77.14
# 4       ANA 2019-01-08   78.24       77.14    99300   7749464.70   78.24
# ...     ...        ...     ...         ...      ...          ...     ...
# 8570    VIS 2019-12-09   48.70       48.76    40236   1958325.66   48.70
# 8571    VIS 2019-12-10   48.16       48.70    60198   2895965.78   48.16
# 8572    VIS 2019-12-11   47.96       48.16    63000   3012462.12   47.96
# 8573    VIS 2019-12-12   48.42       47.96    50218   2429199.80   48.42
# 8574    VIS 2019-12-13   48.64       48.42    62427   3038685.10   48.64
#
#        Alto   Bajo  Promedio
# 0     75.16  72.38   74.3518
# 1     76.60  74.54   75.7687
# ...

# %%
type(df['Fecha'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ###mostrar parte de la fecha

# %%
df['Fecha'][44]
# Out:
# Timestamp('2019-03-05 00:00:00')

# %%
#mostrar parte de la fecha
df['Fecha'][44].year
# Out:
# 2019

# %%
df['Fecha'][44].month
# Out:
# 3

# %%
df['Fecha'][44].day
# Out:
# 5

# %% [markdown]
# ###agregar valores a la fecha

# %%
df_mas5dias = df['Fecha'] + pd.Timedelta(days=5)

# %%
df_mas5dias
# Out:
# 0      2019-01-07
# 1      2019-01-08
# 2      2019-01-09
# 3      2019-01-12
# 4      2019-01-13
#           ...
# 8570   2019-12-14
# 8571   2019-12-15
# 8572   2019-12-16
# 8573   2019-12-17
# 8574   2019-12-18
# Name: Fecha, Length: 8575, dtype: datetime64[ns]

# %% [markdown]
# ##Abrir y escribir archivos

# %%
import pandas as pd

# %%
ruta_excel = "/content/drive/MyDrive/cd_udemy_fg/Compras_desde_ads.xlsx"
ruta_xml ="/content/drive/MyDrive/cd_udemy_fg/Valores+de+acciones.xml"

# %%
#abrir archivo excel
df1 = pd.read_excel(ruta_excel)

# %%
df1
# Out:
#      Id_usuario     Genero  Edad  Salario_estimado  Comprado
# 0      15624510  Masculino    19             19000         0
# 1      15810944  Masculino    35             20000         0
# 2      15668575   Femenino    26             43000         0
# 3      15603246   Femenino    27             57000         0
# 4      15804002  Masculino    19             76000         0
# ..          ...        ...   ...               ...       ...
# 395    15691863   Femenino    46             41000         1
# 396    15706071  Masculino    51             23000         1
# 397    15654296   Femenino    50             20000         1
# 398    15755018  Masculino    36             33000         0
# 399    15594041   Femenino    49             36000         1
#
# [400 rows x 5 columns]

# %%
df2 = pd.read_xml(ruta_xml)

# %%
df2
# Out:
#           date closingValue
# 0   01-05-2023        25,05
# 1   02-05-2023        24,45
# 2   03-05-2023        24,45
# 3   04-05-2023        23,98
# 4   05-05-2023        24,56
# 5   06-05-2023        23,66
# 6   07-05-2023        24,38
# 7   08-05-2023        24,67
# 8   09-05-2023        25,15
# 9   10-05-2023        25,43
# 10  11-05-2023        25,43
# 11  12-05-2023        25,27
# 12  13-05-2023        25,27
# 13  14-05-2023        25,71
# 14  15-05-2023        25,71
# 15  16-05-2023        26,27
# 16  17-05-2023        26,27
# 17  18-05-2023        26,27
# 18  19-05-2023        27,13
# 19  20-05-2023         27,8
# 20  21-05-2023         27,5
# 21  22-05-2023        26,52
# 22  23-05-2023        26,52
# 23  24-05-2023        26,52
# 24  25-05-2023        27,16
# 25  26-05-2023        27,16
# 26  27-05-2023         27,8
# 27  28-05-2023        27,36
# 28  29-05-2023        27,59
# 29  30-05-2023        27,59
# 30  31-05-2023        28,14

# %% [markdown]
# ##creando un archivo

# %%
numeros = {
    'romanos': ['I', 'II', 'III', 'IV'],
    'arabigos': [1,2,3,4],
    'texto': ['uno', 'dos', 'tres', 'cuatro']
}

# %%
df = pd.DataFrame(numeros)

# %%
df
# Out:
#   romanos  arabigos   texto
# 0       I         1     uno
# 1      II         2     dos
# 2     III         3    tres
# 3      IV         4  cuatro

# %%
df['fechas'] = pd.Series(pd.date_range('20240101', periods=4))

# %%
df
# Out:
#   romanos  arabigos   texto     fechas
# 0       I         1     uno 2024-01-01
# 1      II         2     dos 2024-01-02
# 2     III         3    tres 2024-01-03
# 3      IV         4  cuatro 2024-01-04

# %%
df.to_excel("/content/drive/MyDrive/cd_udemy_fg/archivo_test.xlsx", index=False)

# %%
df.to_csv("/content/drive/MyDrive/cd_udemy_fg/archivo_test.csv", index=False)

# %% [markdown]
# ##acceder a elementos del dataframe con "loc" e "iloc"

# %%
import pandas as pd

# %%
df = pd.DataFrame( {
    'col1': [100,200,300],
    'col2': [400,500,600],
    'col3': [700,800,900]}, index=['fila1', 'fila2', 'fila3']
                   )

# %%
df
# Out:
#        col1  col2  col3
# fila1   100   400   700
# fila2   200   500   800
# fila3   300   600   900

# %% [markdown]
# ###loc

# %%
df.loc['fila1']
# Out:
# col1    100
# col2    400
# col3    700
# Name: fila1, dtype: int64

# %%
df.loc[['fila2', 'fila3']]
# Out:
#        col1  col2  col3
# fila2   200   500   800
# fila3   300   600   900

# %%
df.loc['fila2':'fila3']
# Out:
#        col1  col2  col3
# fila2   200   500   800
# fila3   300   600   900

# %%
df.loc[[False, True, False]]
# Out:
#        col1  col2  col3
# fila2   200   500   800

# %%
df.loc[df['col1']>150]
# Out:
#        col1  col2  col3
# fila2   200   500   800
# fila3   300   600   900

# %%
df.loc[:,['col1', 'col2']]
# Out:
#        col1  col2
# fila1   100   400
# fila2   200   500
# fila3   300   600

# %% [markdown]
# ###iloc

# %%
df.iloc[0]
# Out:
# col1    100
# col2    400
# col3    700
# Name: fila1, dtype: int64

# %%
df.iloc[:,[0,1]]
# Out:
#        col1  col2
# fila1   100   400
# fila2   200   500
# fila3   300   600

# %%
df.iloc[1:3]
# Out:
#        col1  col2  col3
# fila2   200   500   800
# fila3   300   600   900

# %%
df.iloc[[0],[0]]
# Out:
#        col1
# fila1   100
